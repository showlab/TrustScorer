# %%
import json
from time import sleep
from pyautogui import *
from assistgpt_client import GUICapture, post_process_code, open_software

task_id = "022"
task_data = json.load(open("../client/TrustBench/ace_test.json"))
capture = GUICapture()
print(f"Query: {task_data[task_id]['query']}")
response = capture.run(task_data[task_id]['query'], software=task_data[task_id]['software'], send_data=True, run_code=True, task_id=task_id, reset=True, port=6006)
